# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish-Sachdev/canadian-surgical-wait-times-analytics/blob/main/Group_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fdsfasdfadsfdasfdsf
fadsfdasfsadfa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3165/893884565.py in <cell line: 0>()
# ----> 1 fdsfasdfadsfdasfdsf
#       2 fadsfdasfsadfa
#
# NameError: name 'fdsfasdfadsfdasfdsf' is not defined
